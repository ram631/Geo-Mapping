# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# # 1. preparing dataset

# %%
# random dates generator

def random_dates(start, end, n):

    start_u = start.value//10**9
    end_u = end.value//10**9

    return pd.to_datetime(np.random.randint(start_u, end_u, n), unit='s')

# %%
# generating 2000 random latitude points between 40.701 and 40.801
r_lat = np.random.uniform(40.701, 40.801, 20000)

# generating 2000 random longitude points between 72.801 west and 73.801 west
r_lon = np.random.uniform(-72.801, -73.801, 20000)

# Assigning start and end date time
start = pd.to_datetime('20-07-2021 19:00:00')
end = pd.to_datetime('20-07-2021 19:01:59')

# generating 2000 random date time points between start and end date time 
dt = random_dates(start, end, 20000)

# generating 2000 ids with 550 unique ids
id1 = np.random.choice(550, 20000, replace=True)

# %%
# preparing a dataframe

t3 = pd.DataFrame()
t3['id'] = id1
t3['latitude'] = r_lat
t3['longitude'] = r_lon
t3['date_time'] = dt

# data time should be string in order for plotly animation to work based on date time
t3['date_str'] = t3['date_time'].apply(lambda x: str(x))
t3
# Out:
#         id   latitude  longitude           date_time             date_str
# 0      543  40.709922 -73.617242 2021-07-20 19:00:10  2021-07-20 19:00:10
# 1      510  40.733468 -73.223637 2021-07-20 19:00:44  2021-07-20 19:00:44
# 2      141  40.707766 -73.362382 2021-07-20 19:01:28  2021-07-20 19:01:28
# 3      206  40.759518 -73.474125 2021-07-20 19:00:20  2021-07-20 19:00:20
# 4      283  40.792364 -73.375900 2021-07-20 19:00:45  2021-07-20 19:00:45
# ...    ...        ...        ...                 ...                  ...
# 19995   19  40.789416 -73.104454 2021-07-20 19:01:56  2021-07-20 19:01:56
# 19996  451  40.775959 -73.131198 2021-07-20 19:01:48  2021-07-20 19:01:48
# 19997  294  40.702644 -73.328202 2021-07-20 19:01:01  2021-07-20 19:01:01
# 19998   28  40.710548 -73.113822 2021-07-20 19:00:38  2021-07-20 19:00:38
# 19999  371  40.736326 -73.683411 2021-07-20 19:01:49  2021-07-20 19:01:49
#
# [20000 rows x 5 columns]

# %%
# sorting id and their respective date time

t3 = t3.set_index(['id','date_time']).sort_index()
t3
# Out:
#                           latitude  longitude             date_str
# id  date_time
# 0   2021-07-20 19:00:02  40.753130 -73.297884  2021-07-20 19:00:02
#     2021-07-20 19:00:09  40.714112 -72.811768  2021-07-20 19:00:09
#     2021-07-20 19:00:10  40.735069 -72.891777  2021-07-20 19:00:10
#     2021-07-20 19:00:10  40.730901 -73.625434  2021-07-20 19:00:10
#     2021-07-20 19:00:14  40.758696 -73.091038  2021-07-20 19:00:14
# ...                            ...        ...                  ...
# 549 2021-07-20 19:01:29  40.782388 -73.142116  2021-07-20 19:01:29
#     2021-07-20 19:01:34  40.781703 -73.398342  2021-07-20 19:01:34
#     2021-07-20 19:01:52  40.732620 -73.172287  2021-07-20 19:01:52
#     2021-07-20 19:01:54  40.769857 -73.037374  2021-07-20 19:01:54
#     2021-07-20 19:01:56  40.747248 -73.760335  2021-07-20 19:01:56
#
# [20000 rows x 3 columns]

# %% [markdown]
# # 2. Visualization

# %%
# visualizing

fig = px.scatter_mapbox(lat=t3['latitude'], lon=t3['longitude'],
                        color_discrete_sequence=["green"], zoom=10, height=500, animation_frame=t3['date_str'])
fig.update_layout(mapbox_style="open-street-map")
fig.layout.geo.lataxis.range = [40.5, 40.9]
fig.layout.geo.lonaxis.range = [-72.7, -73.9]
fig.show()
# Out:
# <div>                            <div id="973a769b-f745-4e0f-8781-80d609924149" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("973a769b-f745-4e0f-8781-80d609924149")) {                    Plotly.newPlot(                        "973a769b-f745-4e0f-8781-80d609924149",                        [{"hovertemplate": "animation_frame=2021-07-20 19:00:02<br>lat=%{lat}<br>lon=%{lon}<extra></extra>", "lat": [40.75313001905695, 40.73393678126634, 40.77570331641315, 40.713188991343955, 40.786421415615614, 40.78511798646609, 40.788893224127825, 40.7673216629979, 40.7771317659392, 40.75774302584215, 40.75369883693612, 40.79643539614985, 40.75367708267379, 40.76022257061533, 40.72697480163023, 40.768283908033716, 40.755636265563844, 40.71458894149274, 40.75768740390311, 40.78442685827117, 40.78410574064584, 40.73829394879008, 40.752364425762565, 40.701312899125696, 40.760715751063906, 40.79211337766932, 40.75208475397407, 40.71214933986733, 40.74095412657087, 40.70792990169539, 40.77479335690983, 40.784409376860964, 40.702544138136716, 40.77231220838783, 40.75563816003788, 40.74918963225491, 40.7670405105093, 40.774468365816794, 40.70216164701152, 40.78636733260129, 40.74552532663358, 40.79721437557231, 40.758882025640176, 40.735011202938836, 40.73003171894165, 40.7012149602415, 40.72145672028423, 40.77870590800711, 40.73195955899497, 40.73440798484268, 40.78882102100059, 40.786068093219875, 40.74762150020093, 40.71071984997474, 40.78953137318172, 40.76950525984883, 40.77325042228689, 40.78994198604355, 40.728555685756874, 40.772131349309, 40.73710183655598, 40.73035572087493, 40.78704726289098, 40.76459435612643, 40.75991791299342, 40.714450141527855, 40.714572804262, 40.70978865223631, 40.73653320861808, 40.793486608700306, 40.71607212903574, 40.71214775121665, 40.70951324265306, 40.76962096741313, 40.751973990809134, 40.7912535101322, 40.78138397143523, 40.75243760474994, 40.73659095648129, 40.79237934166102, 40.76386244299528, 40.774344542227446, 40.71845972647238, 40.75068353004067, 40.76570076647691, 40.70281306822692, 40.726900438015676, 40.75795512013604, 40.7491663470763, 40.712664696938894, 40.7965033890787, 40.731352153773436, 40.765976795011156, 40.77557190130825, 40.78379778964102, 40.79114848187413, 40.763057934862, 40.78572082488789, 40.779936585730674, 40.79721366407978, 40.796067941074654, 40.75896465859394, 40.786996400125915, 40.715358010054445, 40.74621069085354, 40.74500661237463, 40.77530080925443, 40.79425350934098, 40.79999182094172, 40.79889130558781, 40.761966045311546, 40.72172014538602, 40.73216242392105, 40.7681381903508, 40.7742756851572, 40.77974325351156, 40.73748422198947, 40.79470940252286, 40.79528584671137, 40.73729794145359, 40.70574102585011, 40.71136852987896, 40.751362496724134, 40.76264846567422, 40.786826812720214, 40.783833743502846, 40.732957649798394, 40.785202577059806, 40.71452075284633, 40.76270927055209, 40.78914061651013, 40.70193574558715, 40.77728281118217, 40.77914894571368, 40.71041265539727, 40.75890078932924, 40.7838372317211, 40.78244934406132, 40.76009533348603, 40.79342060166219, 40.79329957839517, 40.742366678788585, 40.70461173848027, 40.75454370988032, 40.7088367325425, 40.75571910559469, 40.71899382481953, 40.75858844648684, 40.76898232317453, 40.755068658183085, 40.70847599149453, 40.77379274966254, 40.783801742070935, 40.74639033260322, 40.79787916713398, 40.70247077952588], "legendgroup": "", "lon": [-73.29788439447483, -73.20190995853406, -73.18269636885381, -72.85568904518864, -73.25907663005263, -73.23279168073279, -73.10467142286626, -73.20931048681368, -73.48674232568892, -72.82377225466584, -73.1219981436784, -73.40687277890714, -73.33946861641965, -73.48337497194993, -73.19502729527936, -73.75998602593549, -73.56134023245406, -73.0454748 ...
